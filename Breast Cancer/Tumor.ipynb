# %% [markdown]
# # Breast Cancer Tumor

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
BC = pd.read_csv('breast_cancer_data.csv')
# train = pd.read_csv('titanic_train.csv')

# %%
BC.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
BC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
BC.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
BC.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
BC.drop('Unnamed: 32', axis =1, inplace=True)

# %%
BC.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
BCradiustexture = BC[['radius_mean', 'texture_mean', 'radius_worst', 'texture_worst', 'diagnosis']]

# %%
sns.heatmap(BCradiustexture.corr(), annot = True)

# %%
BCmean = BC[['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean']]
BCdiag = BC['diagnosis']
BCmean1 = BC[['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'diagnosis']]

# %%
plt.figure(figsize = [20,10])
sns.heatmap(BCmean1.corr(), annot = True)

# %%
BCmean1.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean diagnosis
# 0                 0.07871         M
# ...

# %%
sns.pairplot(BCmean1, hue='diagnosis', palette='rainbow')

# %%
sns.lineplot(x='radius_mean', y='texture_mean', data=BCmean1, hue='diagnosis')
plt.title('E')
# Out:
# Text(0.5, 1.0, 'E')

# %%
sns.factorplot(x='diagnosis', y='radius_mean', data=BCmean1, kind='violin')
# Out:
# C:\Users\yomie\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='diagnosis', y='smoothness_mean', data=BCmean1, kind='violin')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='radius_mean', y='texture_mean', data=BCmean1, hue='diagnosis') 
plt.title('Texture vs Radius', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Texture vs Radius')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='radius_mean', y='perimeter_mean', data=BCmean1, hue='diagnosis') 
plt.title('Perimeter vs Radius', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Perimeter vs Radius')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='radius_mean', y='smoothness_mean', data=BCmean1, hue='diagnosis') 
plt.title('smoothness vs Radius', fontsize=20)
# Out:
# Text(0.5, 1.0, 'smoothness vs Radius')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='perimeter_mean', y='smoothness_mean', data=BCmean1, hue='diagnosis') 
plt.title('smoothness vs Perimeter', fontsize=20)
# Out:
# Text(0.5, 1.0, 'smoothness vs Perimeter')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='fractal_dimension_mean', y='texture_mean', data=BCmean1, hue='diagnosis') 
plt.title('Texture vs Fractal Dimension', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Texture vs Fractal Dimension')

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='symmetry_mean', y='smoothness_mean', data=BCmean1, hue='diagnosis') 
plt.title('Smoothness vs Symmetry', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Smoothness vs Symmetry')

# %%
sns.set(rc={'figure.figsize':(19.7, 8.27)})
sns.pairplot(BCmean1, hue='diagnosis', vars=['radius_mean', 'texture_mean'])
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.kdeplot(BCmean1.radius_mean[BCmean1.diagnosis=='M'], label='M', shade=True)
sns.kdeplot(BCmean1.radius_mean[BCmean1.diagnosis=='B'], label='B', shade=True)
plt.xlabel('RADIUS');

# %%
plt.figure(figsize=(8,6))
sns.kdeplot(BCmean1.area_mean[BCmean1.diagnosis=='M'], label='M', shade=True)
sns.kdeplot(BCmean1.area_mean[BCmean1.diagnosis=='B'], label='B', shade=True)
plt.xlabel('AREA');

# %%
plt.figure(figsize=(8,6))
sns.kdeplot(BCmean1.perimeter_mean[BCmean1.diagnosis=='M'], label='M', shade=True)
sns.kdeplot(BCmean1.perimeter_mean[BCmean1.diagnosis=='B'], label='B', shade=True)
plt.xlabel('PERIMETER');

# %%
plt.figure(figsize=(8,6))
sns.kdeplot(BCmean1.smoothness_mean[BCmean1.diagnosis=='M'], label='M', shade=True)
sns.kdeplot(BCmean1.smoothness_mean[BCmean1.diagnosis=='B'], label='B', shade=True)
plt.xlabel('SMOOTHNESS');

# %%
plt.figure(figsize=(8,6))
sns.kdeplot(BCmean1.symmetry_mean[BCmean1.diagnosis=='M'], label='M', shade=True)
sns.kdeplot(BCmean1.symmetry_mean[BCmean1.diagnosis=='B'], label='B', shade=True)
plt.xlabel('SYMMETRY');

# %%
plt.figure(figsize=(20,15))

plt.subplot(221)
sns.kdeplot(BCmean1.smoothness_mean[BCmean1.diagnosis=='M'], label='M', shade=True)
sns.kdeplot(BCmean1.smoothness_mean[BCmean1.diagnosis=='B'], label='B', shade=True)
plt.title('SMOOTHNESS')

plt.subplot(222)
sns.kdeplot(BCmean1.symmetry_mean[BCmean1.diagnosis=='M'], label='M', shade=True)
sns.kdeplot(BCmean1.symmetry_mean[BCmean1.diagnosis=='B'], label='B', shade=True)
plt.title('SYMMETRY')
# Out:
# Text(0.5, 1.0, 'SYMMETRY')

# %%
plt.figure(figsize=(20,15))

plt.subplot(221)
sns.kdeplot(BCmean1.perimeter_mean[BCmean1.diagnosis=='M'], label='M', shade=True)
sns.kdeplot(BCmean1.perimeter_mean[BCmean1.diagnosis=='B'], label='B', shade=True)
plt.title('PERIMETER')

plt.subplot(222)
sns.kdeplot(BCmean1.area_mean[BCmean1.diagnosis=='M'], label='M', shade=True)
sns.kdeplot(BCmean1.area_mean[BCmean1.diagnosis=='B'], label='B', shade=True)
plt.title('AREA')
# Out:
# Text(0.5, 1.0, 'AREA')

# %%
plt.figure(figsize=(20,15))

plt.subplot(221)
sns.kdeplot(BCmean1.perimeter_mean[BCmean1.diagnosis=='M'], label='M', shade=True)
sns.kdeplot(BCmean1.perimeter_mean[BCmean1.diagnosis=='B'], label='B', shade=True)
plt.title('PERIMETER')

plt.subplot(222)
sns.kdeplot(BCmean1.symmetry_mean[BCmean1.diagnosis=='M'], label='M', shade=True)
sns.kdeplot(BCmean1.symmetry_mean[BCmean1.diagnosis=='B'], label='B', shade=True)
plt.title('SYMMETRY')
# Out:
# Text(0.5, 1.0, 'SYMMETRY')

# %%
sns.pairplot(BCmean1, hue='diagnosis', vars=['radius_mean', 'perimeter_mean'])

# %%
sns.pairplot(BCmean1, hue='diagnosis', vars=['radius_mean', 'area_mean'])

# %%
sns.pairplot(BCmean1, hue='diagnosis', vars=['radius_mean', 'area_mean'])

# %%
sns.pairplot(BCmean1, hue='diagnosis', vars=['area_mean', 'perimeter_mean'])

# %%
sns.pairplot(BCmean1, hue='diagnosis', vars=['fractal_dimension_mean', 'texture_mean'])

# %%
sns.pairplot(BCmean1, hue='diagnosis', vars=['symmetry_mean', 'smoothness_mean'])

# %%
sns.pairplot(BCmean1, hue='diagnosis', vars=['symmetry_mean', 'texture_mean'])

# %%
plt.figure(figsize=(12,7))
sns.boxplot(x='diagnosis', y='area_mean', data=BCmean1, palette='winter')
